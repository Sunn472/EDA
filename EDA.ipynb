# %% [markdown]
# # **BIKE DETAIL DATASET**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('BIKE DETAILS.csv')

# %%
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1061 non-null   object
#  1   selling_price      1061 non-null   int64
#  2   year               1061 non-null   int64
#  3   seller_type        1061 non-null   object
#  4   owner              1061 non-null   object
#  5   km_driven          1061 non-null   int64
#  6   ex_showroom_price  626 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 58.2+ KB

# %%
df.shape
# Out:
# (1061, 7)

# %%
df.columns
# Out:
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')

# %%
df[df.duplicated()]
# Out:
#                          name  selling_price  year seller_type      owner  \
# 231     TVS Apache RTR 200 4V          95000  2018  Individual  1st owner
# 508       Bajaj Pulsar 135 LS          20000  2010  Individual  1st owner
# 522         Bajaj Platina 100          20000  2012  Individual  1st owner
# 605  Hero Karizma [2003-2014]          50000  2013  Individual  1st owner
# 607      Honda CB Hornet 160R          70000  2017  Individual  1st owner
# 773  Honda Activa [2000-2015]          23000  2009  Individual  1st owner
#
#      km_driven  ex_showroom_price
# 231       9600                NaN
# 508      80000            64589.0
# 522      16295                NaN
# 605      38000            85766.0
# 607      35000            87719.0
# 773      95000            50267.0

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_copy=df.copy()

# %%
df_copy
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df_copy.duplicated().sum()
# Out:
# 0

# %%
'''
Q1. What is the range of selling prices in the dataset
'''
max_selling_price=df_copy['selling_price'].max()
min_selling_price=df_copy['selling_price'].min()
print(f'The ranges of selling price is : [{min_selling_price},{max_selling_price}]')
# Out:
# The ranges of selling price is : [5000,760000]

# %%
'''
Q2. What is the median selling price for bikes in the dataset
'''
median_selling_price=df_copy['selling_price'].median()
print(f'the median selling price for bikes is: {median_selling_price}')
# Out:
# the median selling price for bikes is: 45000.0

# %%
'''
Q3. What is the most common seller type
'''
most_common_seller_type=df_copy['seller_type'].mode()[0]
print(f'The most common seller type is: {most_common_seller_type}')
# Out:
# The most common seller type is: Individual

# %%
'''
Q4. How many bikes have driven more than 50,000 kilometers
'''
count=df_copy[df_copy['km_driven'] > 50000].shape[0]
print(f'The number of bikes that have driven more than 50,000 kilometers is: {count}')
# Out:
# The number of bikes that have driven more than 50,000 kilometers is: 168

# %%
'''
Q5. What is the average km_driven value for each ownership type
'''
average_km_driven=df_copy.groupby('owner')['km_driven'].mean()
print(f'the average km_driven value for each ownership type: {average_km_driven}')
# Out:
# the average km_driven value for each ownership type: owner
# 1st owner     32732.710240
# 2nd owner     39288.991870
# 3rd owner     33292.181818
# 4th owner    311500.000000
# Name: km_driven, dtype: float64

# %%
'''
Q6. What proportion of bikes are from the year 2015 or older
'''
count=df_copy[df_copy['year'] >= 2015].shape[0]
total_count=df_copy.shape[0]
proportion=count/total_count
print(f'The proportion of bikes that are from the year 2015 or older is: {proportion}')
# Out:
# The proportion of bikes that are from the year 2015 or older is: 0.5289099526066351

# %%
'''
Q7. What is the trend of missing values across the dataset
'''
missing_values=df_copy.isnull().sum()
print(f'The trend of missing values across the dataset: {missing_values}')

#if we want treat the missing value we fill the miising with mean or median
#we go to median beacuse it may be present outlier in it

median_value=df_copy['ex_showroom_price'].median()
df_copy['ex_showroom_price'].fillna(median_value,inplace=True)

#after the teratment of missing value
missing_values1=df_copy.isnull().sum()
print(f'Ater treatment missing values across the dataset: {missing_values1}')
# Out:
# The trend of missing values across the dataset: name                   0
# selling_price          0
# year                   0
# seller_type            0
# owner                  0
# km_driven              0
# ex_showroom_price    433
# dtype: int64
# Ater treatment missing values across the dataset: name                 0
# selling_price        0
# year                 0
# seller_type          0
# owner                0
# km_driven            0
# ex_showroom_price    0
# dtype: int64

# %%
'''
Q8. What is the highest ex_showroom_price recorded, and for which bike
'''
highest_ex_showroom_price=df_copy['ex_showroom_price'].max()
df_copy[df_copy['ex_showroom_price']==highest_ex_showroom_price][['name','ex_showroom_price']]
# Out:
#                            name  ex_showroom_price
# 134  Harley-Davidson Street Bob          1278000.0

# %%
'''
Q9. What is the total number of bikes listed by each seller type
'''
bike_count=df_copy.groupby('seller_type').name.count()
print(f'The total number of bikes listed by each seller type: {bike_count}')
# Out:
# The total number of bikes listed by each seller type: seller_type
# Dealer           6
# Individual    1049
# Name: name, dtype: int64

# %%
'''
Q10. What is the relationship between selling_price and km_driven for first-owner
bikes
'''
first_owner_bikes=df_copy[df_copy['owner']=='1st owner']
selling_price=first_owner_bikes['selling_price']
km_driven=first_owner_bikes['km_driven']

#due high density and too much overlapping we can't go with scatter plot
plt.figure(figsize=(10,6))
sns.lineplot(x=selling_price,y=km_driven,marker='o',ci=None)
plt.title('The relationship between selling_price and km_driven for first-owner bikes')
plt.ylabel('Kilometers Driven')
plt.xlabel('Selling Price')
plt.tight_layout()
plt.show()

#insights
#more km_drive less selling price it shows inverse realationship

# %%
'''
Q11. Identify and remove outliers in the km_driven column using the IQR method
'''

Q1 = df_copy['km_driven'].quantile(0.25)
Q3 = df_copy['km_driven'].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Find outliers (values outside the bounds)
outliers = (df_copy[(df_copy['km_driven'] < lower_bound) | (df_copy['km_driven'] > upper_bound)])['km_driven'].value_counts()

# Print the outliers
print("Outliers in km_driven column:")
print(outliers)

#Removal of outlier
df_filtered=df_copy[(df_copy['km_driven'] >= lower_bound) & (df_copy['km_driven'] <= upper_bound)]
# Out:
# Outliers in km_driven column:
# km_driven
# 100000    14
# 500000     2
# 120000     2
# 90000      2
# 93000      2
# 880000     1
# 213000     1
# 89000      1
# 127000     1
# 450000     1
# 345000     1
# 240000     1
# 101000     1
# 98000      1
# 130000     1
# 340000     1
# 585659     1
# 95000      1
# 646000     1
# 99000      1
# 92233      1
# Name: count, dtype: int64

# %%
df_copy
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df_filtered.shape
# Out:
# (1017, 7)

# %%
'''
Q12. Perform a bivariate analysis to visualize the relationship between year and
selling_price
'''
plt.figure(figsize=(10,6))
sns.barplot(x=df_copy['year'],y=df_copy['selling_price'])
plt.title('The relationship between year and selling_price')
plt.xlabel('year')
plt.ylabel('selling_price')
plt.xticks(rotation=60)
plt.show()

# %%
'''
Q13. What is the average depreciation in selling price based on the bike's age
(current year - manufacturing year)
'''
current_year=2025
df_copy['age']=current_year-df_copy['year']
df_copy['depreciation']=df_copy['selling_price']-df_copy['ex_showroom_price']
average_depreciation=df_copy['depreciation']/df_copy['age']
average_depreciation
# Out:
# 0       17041.250000
# 1       -3469.062500
# 2         269.428571
# 3       -2464.300000
# 4       -3768.035714
#             ...
# 1056    -2333.333333
# 1057    -2692.307692
# 1058    -3500.000000
# 1059    -2875.000000
# 1060    -3823.529412
# Length: 1055, dtype: float64

# %%
df_copy
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price  age  depreciation
# ...

# %%
'''
Q14. Which bike names are priced significantly above the average price for their
manufacturing year
 '''
# Calculate the average selling price and standard deviation for each year

avg_price=df_copy.groupby('year')['selling_price'].mean()
std_dev=df_copy.groupby('year')['selling_price'].std()

#merge the avg and std with original dataframe
df_with_stats = df_copy.merge(avg_price, on='year', suffixes=('', '_avg'))
df_with_stats = df_with_stats.merge(std_dev, on='year', suffixes=('', '_std'))

df_above_avg = df_with_stats[df_with_stats['selling_price'] > (df_with_stats['selling_price_avg'] + df_with_stats['selling_price_std'])]

print(df_above_avg[['name', 'year', 'selling_price', 'selling_price_avg', 'selling_price_std']])
# Out:
#                                      name  year  selling_price  \
# 2     Royal Enfield Classic Gunmetal Grey  2018         150000
# 7    Royal Enfield Bullet 350 [2007-2011]  2008         180000
# 13                          Yamaha YZF R3  2019         365000
# 18    Royal Enfield Classic Gunmetal Grey  2018         150000
# 24          Royal Enfield Thunderbird 350  2016         110000
# ..                                    ...   ...            ...
# 970             Royal Enfield Classic 350  2015         110000
# 973             Royal Enfield Thunder 500  2015         105000
# 977             Royal Enfield Classic 350  2015         100000
# 978             Royal Enfield Classic 500  2014          95000
# 979             Royal Enfield Classic 500  2011          90000
#
#      selling_price_avg  selling_price_std
# 2         87603.915385       46569.428146
# 7         34289.285714       35197.257251
# 13       119689.511628       96703.350677
# ...

# %%
'''
Q15. Develop a correlation matrix for numeric columns and visualize it using a
heatmap.
'''
corr=df_copy.corr(numeric_only=True)
plt.figure(figsize=(12,10))
sns.heatmap(corr,annot=True,cmap='coolwarm',fmt='.2f')
plt.show()

# %% [markdown]
# # **Car Sale Dataset**

# %%
df1=pd.read_csv('Car Sale.csv')

# %%
'''
Q1. What is the average selling price of cars for each dealer, and how does it
compare across different dealers
'''
#average selling price of cars for each dealer
avg_selling_price=df1.groupby('Dealer_Name')['Price ($)'].mean()
print(f'The average selling price of cars for each dealer: {avg_selling_price}')


#compare across different dealers
plt.figure(figsize=(10,6))
sns.barplot(x=avg_selling_price.index,y=avg_selling_price.values)
plt.title('The average selling price of cars for each dealer')
plt.xlabel('Dealer Name')
plt.ylabel('Average Selling Price($)')
plt.xticks(rotation=90)
plt.show()
# Out:
# The average selling price of cars for each dealer: Dealer_Name
# Buddy Storbeck's Diesel Service Inc                27217.261563
# C & M Motors Inc                                   28111.755200
# Capitol KIA                                        28189.703822
# Chrysler Plymouth                                  27555.526400
# Chrysler of Tri-Cities                             28123.091054
# Classic Chevy                                      28602.014446
# Clay Johnson Auto Sales                            27816.027113
# Diehl Motor CO Inc                                 27993.929487
# Enterprise Rent A Car                              28312.580800
# Gartner Buick Hyundai Saab                         28247.621019
# Hatfield Volkswagen                                27853.712242
# Iceberg Rentals                                    28522.958533
# McKinney Dodge Chrysler Jeep                       27684.096979
# Motor Vehicle Branch Office                        27956.739617
# ...

# %%
'''
Q2. Which car brand (Company) has the highest variation in prices, and what does
this tell us about the pricing trends
'''
price_std = df1.groupby('Company')['Price ($)'].std().sort_values(ascending=False)

print(f'The car brand (Company) has the highest variation in prices: {price_std.index[0]}')


plt.figure(figsize=(12, 6))
sns.boxplot(x='Company', y='Price ($)', data=df1)
plt.xticks(rotation=45)
plt.title('Price Variation by Company')
plt.show()
# Out:
# The car brand (Company) has the highest variation in prices: Lincoln

# %%
'''
Q3. What is the distribution of car prices for each transmission type, and how do
the interquartile ranges compare
'''
# Create a boxplot of price distribution by transmission type
sns.boxplot(x='Transmission', y='Price ($)', data=df1)
plt.title('Car Price Distribution by Transmission Type')
plt.ylabel('Price')
plt.xlabel('Transmission Type')
plt.show()


def iqr(col):
    Q1=col.quantile(0.25)
    Q3=col.quantile(0.75)
    IQR=Q3-Q1
    return IQR

iqr_values=df1.groupby('Transmission')['Price ($)'].apply(iqr)
print(f'The interquartile ranges compare: {iqr_values}')
# Out:
# The interquartile ranges compare: Transmission
# Auto      16500.0
# Manual    17000.0
# Name: Price ($), dtype: float64

# %%
'''
Q4. What is the distribution of car prices across different regions
'''
# Create a boxplot of price distribution by region
sns.boxplot(x='Dealer_Region', y='Price ($)', data=df1)
plt.title('Car Price Distribution by Region')
plt.ylabel('Price')
plt.xlabel('Region')
plt.show()

# %%
'''
Q5. What is the distribution of cars based on body styles
'''
# Create a countplot of car body styles
sns.countplot(x='Body Style', data=df1)
plt.title('Distribution of Cars by Body Style')
plt.xlabel('Body Style')
plt.ylabel('Count')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'SUV'),
#   Text(1, 0, 'Passenger'),
#   Text(2, 0, 'Hatchback'),
#   Text(3, 0, 'Hardtop'),
#   Text(4, 0, 'Sedan')])

# %%
'''
How does the average selling price of cars vary by customer gender and annual
income
'''
df1.columns = df1.columns.str.strip()

df1 = df1[(df1['Annual Income'] > 0) & (df1['Price ($)'] > 0)]

income_bins = [0, 50000, 100000, 250000, 500000, 1000000, 2000000]
income_labels = ['<50k', '50k-100k', '100k-250k', '250k-500k', '500k-1M', '1M+']
df1['Income Group'] = pd.cut(df1['Annual Income'], bins=income_bins, labels=income_labels)

grouped = df1.groupby(['Gender', 'Income Group'])['Price ($)'].mean().reset_index()

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(data=grouped, x='Income Group', y='Price ($)', hue='Gender')
plt.title('Average Car Price by Gender and Income Group')
plt.ylabel('Average Price ($)')
plt.xlabel('Income Group')
plt.tight_layout()
plt.show()

# %%
'''
Q7. What is the distribution of car prices by region, and how does the number
of cars sold vary by region
'''

# Calculate summary statistics for car prices by region
price_stats = df1.groupby('Dealer_Region')['Price ($)'].describe()
print("Price Distribution Statistics by Region:")
print(price_stats)

#Count the number of cars sold per region
sales_count = df1['Dealer_Region'].value_counts()
print("\nNumber of Cars Sold by Region:")
print(sales_count)


#Visualize the number of cars sold per region using a bar plot
plt.figure(figsize=(12, 6))
sns.countplot(x='Dealer_Region', data=df1, order=sales_count.index)
plt.title('Number of Cars Sold by Region')
plt.xlabel('Region')
plt.ylabel('Number of Cars Sold')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Price Distribution Statistics by Region:
#                 count          mean           std     min      25%      50%  \
# Dealer_Region
# Aurora         3130.0  28334.626837  15026.207252  9000.0  18001.0  23000.0
# Austin         4135.0  28341.603628  14903.884549  9000.0  18001.0  23801.0
# Greenville     3128.0  28180.819054  15101.538328  1200.0  18001.0  22500.0
# Janesville     3821.0  27833.350955  14344.995638  4300.0  18001.0  23000.0
# Middletown     3128.0  27856.338875  14619.842395  1700.0  18000.0  22750.0
# Pasco          3131.0  28119.039923  14659.315941  9000.0  18500.5  23000.0
# Scottsdale     3433.0  27954.958928  14902.916820  1450.0  18000.0  22600.0
#
#                    75%      max
# Dealer_Region
# Aurora         35000.0  85800.0
# Austin         35001.0  85601.0
# Greenville     34500.0  85200.0
# Janesville     34000.0  85400.0
# Middletown     34000.0  85300.0
# Pasco          34000.0  85600.0
# Scottsdale     33500.0  85001.0
#
# ...

# %%
'''
Q8.  How does the average car price differ between cars with different engine
sizes
'''

df1['Engine'] = df1['Engine'].str.replace('Â', '').str.strip()

avg_price_by_engine = df1.groupby('Engine')['Price ($)'].mean().sort_values(ascending=False)
print("\nAverage price by engine type:")
print(avg_price_by_engine)

# Visualize the distribution
plt.figure(figsize=(12, 6))
sns.boxplot(x='Engine', y='Price ($)', data=df1)
plt.title('Car Price Distribution by Engine Type')
plt.xticks(rotation=45)
plt.show()
# Out:
# Average price by engine type:
# Engine
# Double Overhead Camshaft    28248.525972
# Overhead Camshaft           27914.710631
# Name: Price ($), dtype: float64

# %%
'''
Q9.  How do car prices vary based on the customer’s annual income bracket
'''
print(df1.isnull().sum())

# Create income brackets
income_bins = [0, 30000, 70000, 150000, 300000, 600000, 1000000, 2000000, 5000000, np.inf]
income_labels = ['<30K', '30K-70K', '70K-150K', '150K-300K', '300K-600K',
                 '600K-1M', '1M-2M', '2M-5M', '>5M']

df1['Income_Bracket'] = pd.cut(df1['Annual Income'], bins=income_bins, labels=income_labels)

# Analyze price distribution by income bracket
plt.figure(figsize=(12, 6))
sns.boxplot(x='Income_Bracket', y='Price ($)', data=df1, order=income_labels)
plt.title('Car Price Distribution by Income Bracket')
plt.xlabel('Annual Income Bracket')
plt.ylabel('Car Price ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Car_id              0
# Date                0
# Customer Name       1
# Gender              0
# Annual Income       0
# Dealer_Name         0
# Company             0
# Model               0
# Engine              0
# Transmission        0
# Color               0
# Price ($)           0
# Dealer_No           0
# Body Style          0
# Phone               0
# Dealer_Region       0
# Income Group     1341
# dtype: int64

# %%
'''
Q10. What are the top 5 car models with the highest number of sales, and
how does their price distribution look
'''

top_models = df1['Model'].value_counts().head(5)
print("Top 5 Car Models by Number of Sales:")
print(top_models)

top_model_names = top_models.index
filtered_df1 = df1[df1['Model'].isin(top_model_names)]

price_stats = filtered_df1.groupby('Model')['Price ($)'].describe()
print("\nPrice Distribution Statistics for Top 5 Models:")
print(price_stats)

for model in top_model_names:
    plt.figure(figsize=(8, 4))
    sns.histplot(filtered_df1[filtered_df1['Model'] == model]['Price ($)'], bins=20, kde=True)
    plt.title(f'Price Distribution for {model}')
    plt.xlabel('Price ($)')
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()
# Out:
# Top 5 Car Models by Number of Sales:
# Model
# Diamante      418
# Silhouette    411
# Prizm         411
# Passat        391
# Ram Pickup    383
# Name: count, dtype: int64
#
# Price Distribution Statistics for Top 5 Models:
#             count          mean           std      min      25%      50%  \
# Model
# Diamante    418.0  22268.303828   9770.768958  12000.0  18000.0  19001.0
# Passat      391.0  19600.728900   8218.521683   9000.0  12001.0  20000.0
# Prizm       411.0  22838.457421   8012.531045  15000.0  16000.0  22000.0
# Ram Pickup  383.0  27820.864230  13297.609534  16000.0  19000.0  21000.0
# Silhouette  411.0  29858.513382  17940.571762  12000.0  14001.0  25000.0
#
#                 75%      max
# Model
# Diamante    22000.0  49801.0
# Passat      27001.0  32501.0
# Prizm       25000.0  44700.0
# Ram Pickup  39300.0  57750.0
# Silhouette  34500.0  60750.0

# %%
'''
Q11. How does car price vary with engine size across different car colors, and
which colors have the highest price variation
'''
price_stats = df1.groupby(['Engine', 'Color'])['Price ($)'].agg(['mean', 'std', 'count']).reset_index()
print("Price Statistics by Engine Type and Color:")
print(price_stats)

#Calculate price variation (standard deviation) for each color
color_variation = df1.groupby('Color')['Price ($)'].std().sort_values(ascending=False)
print("\nPrice Variation (Standard Deviation) by Color:")
print(color_variation)

#Visualize mean prices by engine type and color using a point plot
plt.figure(figsize=(14, 8))
sns.pointplot(x='Engine', y='Price ($)', hue='Color', data=df1, dodge=True, markers='o', linestyles='-')
plt.title('Mean Car Price by Engine Type and Color')
plt.xlabel('Engine Type')
plt.ylabel('Mean Car Price ($)')
plt.legend(title='Color')
plt.tight_layout()
plt.show()
# Out:
# Price Statistics by Engine Type and Color:
#                      Engine       Color          mean           std  count
# 0  Double Overhead Camshaft       Black  25766.451103  12418.674126   4172
# 1  Double Overhead Camshaft  Pale White  30347.987460  14402.413401   5901
# 2  Double Overhead Camshaft         Red  27434.392314  13499.354247   2498
# 3         Overhead Camshaft       Black  31732.967164  17457.405345   3685
# 4         Overhead Camshaft  Pale White  24327.767694  13000.103061   5355
# 5         Overhead Camshaft         Red  30153.405229  17346.642554   2295
#
# Price Variation (Standard Deviation) by Color:
# Color
# Red           15519.360962
# Black         15286.065976
# Pale White    14077.346859
# Name: Price ($), dtype: float64

# %%
'''
Q11. Is there any seasonal trend in car sales based on the date of sale
'''
df1['Date'] = pd.to_datetime(df1['Date'], format='%m/%d/%Y')

#Extract month and year from Date
df1['Month'] = df1['Date'].dt.month
df1['Year'] = df1['Date'].dt.year

#Define seasons based on months
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Fall'

df1['Season'] = df1['Month'].apply(get_season)

# Count sales by month
monthly_sales = df1['Month'].value_counts().sort_index()
monthly_sales.index = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
print("Number of Cars Sold by Month:")
print(monthly_sales)

#Count sales by season
seasonal_sales = df1['Season'].value_counts().reindex(['Winter', 'Spring', 'Summer', 'Fall'])
print("\nNumber of Cars Sold by Season:")
print(seasonal_sales)

#Visualize sales by month
plt.figure(figsize=(12, 6))
sns.barplot(x=monthly_sales.index, y=monthly_sales.values)
plt.title('Car Sales by Month')
plt.xlabel('Month')
plt.ylabel('Number of Cars Sold')
plt.tight_layout()
plt.show()

# Visualize sales by season
plt.figure(figsize=(10, 6))
sns.barplot(x=seasonal_sales.index, y=seasonal_sales.values)
plt.title('Car Sales by Season')
plt.xlabel('Season')
plt.ylabel('Number of Cars Sold')
plt.tight_layout()
plt.show()

#Visualize monthly sales trend over years (if multiple years exist)
yearly_monthly_sales = df1.groupby(['Year', 'Month']).size().unstack().fillna(0)
plt.figure(figsize=(14, 8))
sns.heatmap(yearly_monthly_sales, cmap='Blues', annot=True, fmt='.0f')
plt.title('Car Sales by Month and Year')
plt.xlabel('Month')
plt.ylabel('Year')
plt.xticks(ticks=range(12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.tight_layout()
plt.show()
# Out:
# Number of Cars Sold by Month:
# Jan     790
# Feb     735
# Mar    1535
# Apr    1655
# May    1895
# Jun    1715
# Jul    1725
# Aug    1705
# Sep    3305
# Oct    1830
# Nov    3470
# Dec    3546
# Name: count, dtype: int64
#
# Number of Cars Sold by Season:
# Season
# Winter    5071
# Spring    5085
# Summer    5145
# Fall      8605
# Name: count, dtype: int64

# %%
'''
Q13. How does the car price distribution change when considering different
combinations of body style and transmission type
'''

# Create a combined column for Body Style and Transmission
df1['Body_Transmission'] = df1['Body Style'] + ' - ' + df1['Transmission']

#Calculate summary statistics for car prices by Body Style and Transmission
price_stats = df1.groupby(['Body Style', 'Transmission'])['Price ($)'].describe().reset_index()
print("Price Distribution Statistics by Body Style and Transmission:")
print(price_stats)

#Count the number of cars for each combination
combo_counts = df1['Body_Transmission'].value_counts()
print("\nNumber of Cars by Body Style and Transmission Combination:")
print(combo_counts)


# Visualize mean prices using a point plot
plt.figure(figsize=(14, 8))
sns.pointplot(x='Body Style', y='Price ($)', hue='Transmission', data=df1, dodge=True, markers='o', linestyles='-')
plt.title('Mean Car Price by Body Style and Transmission')
plt.xlabel('Body Style')
plt.ylabel('Mean Car Price ($)')
plt.legend(title='Transmission')
plt.tight_layout()
plt.show()
# Out:
# Price Distribution Statistics by Body Style and Transmission:
#   Body Style Transmission   count          mean           std      min  \
# 0    Hardtop         Auto  1408.0  31520.188210  13687.756740  12000.0
# 1    Hardtop       Manual  1563.0  27016.943698  14072.501848  11000.0
# 2  Hatchback         Auto  3458.0  25910.544824  13144.014337   4200.0
# 3  Hatchback       Manual  2670.0  28702.550562  16284.049616   1700.0
# 4  Passenger         Auto  2020.0  28915.835149  13946.481932   9000.0
# 5  Passenger       Manual  1925.0  28969.521039  18523.684163  10000.0
# 6        SUV         Auto  3086.0  27501.404407  13299.927913   1200.0
# 7        SUV       Manual  3288.0  26079.019161  14621.526541   2200.0
# 8      Sedan         Auto  2599.0  29955.294344  14310.910860  12000.0
# 9      Sedan       Manual  1889.0  29664.271572  15440.056434  11000.0
#
#        25%      50%      75%      max
# 0  21001.0  27000.0  43125.0  75501.0
# 1  17575.5  22001.0  29000.0  82500.0
# ...

# %%
'''
Q14. What is the correlation between car price, engine size, and annual
income of customers, and how do these features interact
'''

numerical_features = ['Price ($)', 'Annual Income']
correlation_matrix = df1[numerical_features].corr()

print("Correlation Matrix (Price and Annual Income):")
print(correlation_matrix)

#Summary statistics by Engine type for Price and Annual Income
engine_stats = df1.groupby('Engine')[['Price ($)', 'Annual Income']].agg(['mean', 'std', 'count']).reset_index()
print("\nSummary Statistics by Engine Type:")
print(engine_stats)

# Step 3: Visualize correlation between Price and Annual Income
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Annual Income', y='Price ($)', hue='Engine', style='Engine', data=df1, alpha=0.6)
plt.title('Car Price vs. Annual Income by Engine Type')
plt.xlabel('Annual Income ($)')
plt.ylabel('Car Price ($)')
plt.tight_layout()
plt.show()

# Step 4: Visualize Price distribution by Engine type
plt.figure(figsize=(12, 6))
sns.boxplot(x='Engine', y='Price ($)', data=df1)
plt.title('Car Price Distribution by Engine Type')
plt.xlabel('Engine Type')
plt.ylabel('Car Price ($)')
plt.tight_layout()
plt.show()

# Step 5: Visualize Annual Income distribution by Engine type
plt.figure(figsize=(12, 6))
sns.boxplot(x='Engine', y='Annual Income', data=df1)
plt.title('Annual Income Distribution by Engine Type')
plt.xlabel('Engine Type')
plt.ylabel('Annual Income ($)')
plt.tight_layout()
plt.show()

# Step 6: Pairplot to explore interactions
sns.pairplot(df1, vars=['Price ($)', 'Annual Income'], hue='Engine', diag_kind='kde')
plt.suptitle('Pairplot of Price and Annual Income by Engine Type', y=1.02)
plt.show()

# Step 7: Heatmap of correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation Heatmap of Price and Annual Income')
plt.tight_layout()
plt.show()
# Out:
# Correlation Matrix (Price and Annual Income):
#                Price ($)  Annual Income
# Price ($)       1.000000       0.012065
# Annual Income   0.012065       1.000000
#
# Summary Statistics by Engine Type:
#                      Engine     Price ($)                       Annual Income  \
#                                      mean           std  count           mean
# 0  Double Overhead Camshaft  28248.525972  13747.070597  12571  835351.185745
# 1         Overhead Camshaft  27914.710631  15862.871978  11335  825837.503308
#
#
#              std  count
# 0  721305.449600  12571
# 1  718561.635469  11335

# %%
'''
Q15. How does the average car price vary across different car models
and engine types?
'''

avg_price = df1.groupby(['Model', 'Engine'])['Price ($)'].agg(['mean', 'count']).reset_index()
avg_price['mean'] = avg_price['mean'].round(2)
print("Average Car Price by Model and Engine Type:")
print(avg_price)


pivot_table = avg_price.pivot(index='Model', columns='Engine', values='mean')
print("\nPivot Table of Average Car Price by Model and Engine Type:")
print(pivot_table)



# Step 4: Visualize average prices using a grouped bar plot
plt.figure(figsize=(14, 8))
sns.barplot(x='Model', y='Price ($)', hue='Engine', data=df1, estimator='mean')
plt.title('Average Car Price by Model and Engine Type')
plt.xlabel('Car Model')
plt.ylabel('Average Price ($)')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Engine Type')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# Average Car Price by Model and Engine Type:
#         Model                    Engine      mean  count
# 0       3-Sep  Double Overhead Camshaft  37986.38    171
# 1      3000GT  Double Overhead Camshaft  22764.33    156
# 2      3000GT         Overhead Camshaft  21770.66    147
# 3        300M  Double Overhead Camshaft  21394.89    243
# 4        323i  Double Overhead Camshaft  16744.63    223
# ..        ...                       ...       ...    ...
# 256  Windstar         Overhead Camshaft  17100.27     22
# 257  Wrangler  Double Overhead Camshaft  21145.29     95
# 258  Wrangler         Overhead Camshaft  18742.94     69
# 259    Xterra  Double Overhead Camshaft  15940.46     74
# 260    Xterra         Overhead Camshaft  31072.50     18
#
# [261 rows x 4 columns]
#
# Pivot Table of Average Car Price by Model and Engine Type:
# Engine    Double Overhead Camshaft  Overhead Camshaft
# Model
# 3-Sep                     37986.38                NaN
# ...

# %% [markdown]
# # **Amazon Sales Data**

# %%
df2=pd.read_csv('amazon.csv')

# %%
'''
Q1.What is the average rating for each product category
'''

df2['rating'] = df2['rating'].str.replace('|', '')

df2['rating'] = pd.to_numeric(df2['rating'], errors='coerce')

avg_rating=df2.groupby('category').rating.mean()
print(f'the average rating for each product category: {avg_rating}')
# Out:
# the average rating for each product category: category
# Car&Motorbike|CarAccessories|InteriorAccessories|AirPurifiers&Ionizers                                                    3.800000
# Computers&Accessories|Accessories&Peripherals|Adapters|USBtoUSBAdapters                                                   4.150000
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCHeadsets                                           3.500000
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones                                        3.600000
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCSpeakers                                           4.050000
#                                                                                                                             ...
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|GelInkRollerballPens        4.250000
# ...

# %%
'''
Q2. What are the top rating_count products by category
'''
top_rating_count=df2.groupby('category').rating.max()
print(f'the top rating_count products by category: {top_rating_count}')
# Out:
# the top rating_count products by category: category
# Car&Motorbike|CarAccessories|InteriorAccessories|AirPurifiers&Ionizers                                                    3.8
# Computers&Accessories|Accessories&Peripherals|Adapters|USBtoUSBAdapters                                                   4.3
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCHeadsets                                           3.5
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones                                        3.9
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCSpeakers                                           4.1
#                                                                                                                          ...
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|GelInkRollerballPens        4.3
# ...

# %%
'''
Q3. What is the distribution of discounted prices vs. actual prices
'''
df2['discounted_price']=df2['discounted_price'].str.replace('₹','').str.replace(',','')
df2['actual_price']=df2['actual_price'].str.replace('₹','').str.replace(',','')
df2['discounted_price']=df2['discounted_price'].astype(float)
df2['actual_price']=df2['actual_price'].astype(float)

sns.scatterplot(x=df2['discounted_price'],y=df2['actual_price'])
plt.title('Distribution of discounted prices vs. actual prices')
plt.xlabel('Discounted Price')
plt.ylabel('Actual Price')
plt.show()

# %%
'''
Q4. How does the average discount percentage vary across categories
'''

df2['discount_percentage']=df2.discount_percentage.str.replace('%','')
df2['discount_percentage']=df2['discount_percentage'].astype(float)


# Extract top-level category (before the first '|')
df2['main_category'] = df2['category'].str.split('|').str[0]

# Calculate average discount by main category
avg_discount_by_category = df2.groupby('main_category')['discount_percentage'].mean().sort_values(ascending=False)

# Visualization
plt.figure(figsize=(12, 6))
avg_discount_by_category.plot(kind='bar', color='skyblue')
plt.title('Average Discount Percentage by Main Category')
plt.xlabel('Category')
plt.ylabel('Average Discount Percentage')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Display the numerical results
print("Average Discount Percentage by Category:")
print(avg_discount_by_category.round(2))
# Out:
# Average Discount Percentage by Category:
# main_category
# HomeImprovement          57.50
# Computers&Accessories    54.02
# Health&PersonalCare      53.00
# Electronics              50.83
# MusicalInstruments       46.00
# Car&Motorbike            42.00
# Home&Kitchen             40.12
# OfficeProducts           12.35
# Toys&Games                0.00
# Name: discount_percentage, dtype: float64

# %%
'''
Q5. What are the most popular product names
'''

df2['rating_count'] = df2['rating_count'].str.replace(',', '')
df2['rating_count']=df2['rating_count'].astype(float)

product_popularity = df2.groupby('product_name').agg({
    'rating_count': 'sum',
    'rating': 'mean'}).sort_values('rating_count', ascending=False).head(1)


# Display the top products
print("Top Most Popular Products:")
print(product_popularity[['rating_count', 'rating']].head(1))
# Out:
# Top Most Popular Products:
#                                                     rating_count  rating
# product_name
# AmazonBasics Flexible Premium HDMI Cable (Black...      853945.0     4.4

# %%
'''
Q6.What are the most popular product keywords
'''
from collections import Counter
import re

def extract_keywords(text):
    # Remove special characters and split into words
    words = re.findall(r'\w+', text.lower())
    # Remove common stop words
    stop_words = {'and', 'for', 'the', 'with', 'this', 'that', 'your', 'you', 'are', 'from', 'has', 'have', 'was', 'were', 'its', 'it', 'in', 'on', 'at', 'to', 'of', 'a', 'an', 'is', 'as', 'be', 'by'}
    return [word for word in words if word not in stop_words and len(word) > 2]

# Combine product names and about_product for keyword analysis
all_text = ' '.join(df2['product_name'].fillna('')) + ' ' + ' '.join(df2['about_product'].fillna(''))
keywords = extract_keywords(all_text)

# Get top keywords
keyword_counts = Counter(keywords)
top_keywords = keyword_counts.most_common(1)

print("\nTop Product Keywords:")
for word, count in top_keywords:
    print(f"{word}: {count}")
# Out:
# Top Product Keywords:
# usb: 1647

# %%
'''
Q7. What are the most popular product reviews
'''
from textblob import TextBlob


df2['review_content'] = df2['review_content'].str.lower().str.replace('[^\w\s]', '')


df2['review_length'] = df2['review_content'].str.split().str.len()


def get_common_phrases(text_series, n=3, top=20):
    phrases = []
    for text in text_series.dropna():
        words = text.split()
        phrases.extend([' '.join(words[i:i+n]) for i in range(len(words)-n+1)])
    return Counter(phrases).most_common(top)

common_phrases = get_common_phrases(df2['review_content'])

print("Most Common Review Phrases:")
for phrase, count in common_phrases:
    print(f"{phrase}: {count}")
# Out:
# Most Common Review Phrases:
# if you are: 176
# there is no: 135
# and easy to: 134
# in this price: 129
# easy to use: 126
# it is a: 118
# at this price: 115
# is very good: 110
# is a good: 105
# using it for: 102
# quality is good: 101
# value for money: 99
# is good and: 98
# it is not: 95
# is good but: 95
# could have been: 94
# to use and: 94
# have been using: 93
# sound quality is: 92
# the product is: 91

# %%
'''
Q8. What is the correlation between discounted_price and rating
'''
corr=df2['discounted_price'].corr(df2['rating'])
print(f'The correlation between discounted_price and rating: {corr}')

sns.heatmap(df2[['discounted_price','rating']].corr(),annot=True,cmap='coolwarm',fmt='.2f')
plt.show()
# Out:
# The correlation between discounted_price and rating: 0.12033741712288548

# %%
'''
Q9. What are the Top 5 categories based on the highest rating
'''

def get_primary_category(category_str):
    if pd.isna(category_str):
        return None
    primary = category_str.split('|')[0]
    return primary.strip()

df2['primary_category'] = df2['category'].apply(get_primary_category)


category_ratings = df2.groupby('primary_category')['rating'].mean().sort_values(ascending=False)

top_5_categories = category_ratings.head(5)

print("Top 5 Categories by Average Rating:")
print(top_5_categories)
# Out:
# Top 5 Categories by Average Rating:
# primary_category
# OfficeProducts           4.309677
# Toys&Games               4.300000
# HomeImprovement          4.250000
# Computers&Accessories    4.154967
# Electronics              4.081749
# Name: rating, dtype: float64

# %% [markdown]
# Q10..  Identify any potential areas for improvement or optimization based on the data analysis
# # New Section
#
#
# ANS:-
#
# Based on the analysis of the "amazon.csv" dataset, which contains product details, pricing, ratings, and customer reviews for various electronic and kitchen appliances, several potential areas for improvement or optimization can be identified for stakeholders such as Amazon, product manufacturers, and sellers. These insights leverage patterns in pricing, customer feedback, product performance, and market trends to enhance product offerings, customer satisfaction, and operational efficiency. Below, I outline key areas for improvement, supported by findings from the dataset, and suggest actionable optimizations.
#
# 1. Product Quality and Durability
# Findings:
# Customer Complaints on Durability: Several products, particularly USB cables (e.g., Sounce USB Cable, Ambrane Micro USB Cable), received feedback about durability issues, such as fraying or connectors failing after a few months (e.g., "pin has stopped charging from one side" for Portronics Konnect L, "micro to type c connector stopped working after few days" for boAt Deuce USB 300).
# Low Ratings for Some Products: Products like the IONIX Tap Filter (2.9 rating, 159 reviews) and NGI Store Pet Hair Remover (3.1 rating, 2 reviews) have low ratings due to performance issues (e.g., "Doesn't purify water," "Does not work as advertised").
# Battery and Motor Issues: Kitchen appliances like the KNOWZA Milk Frother and 4-in-1 Electric Vegetable Cutter received complaints about weak motors or battery-related issues (e.g., "no On/Off button," "motor, blade are poor").
#
#
# 2. Opportunities for Improvement:
#
# Enhance Material Quality: For cables, use more durable materials (e.g., reinforced connectors, thicker braiding) to extend lifespan and reduce failure rates.
# Improve Low-Rated Products: For products like the IONIX Tap Filter and NGI Pet Hair Remover, redesign core components (e.g., improve filter media, enhance adhesive properties) to meet advertised claims.
# Optimize Battery-Powered Devices: For frothers and choppers, include rechargeable batteries or clear battery specifications, and add user-friendly features like On/Off switches.
# Quality Assurance: Implement stricter quality control checks before distribution to address issues like "green paste/fungus" in Ambrane cables or "broken measuring cup" in the Prestige Rice Cooker.

# %% [markdown]
# # **SPOTIFY**

# %%
df3=pd.read_csv('spotify.csv')
df3
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 435  French Montana                                    Splash Brothers
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
# 439       Rick Ross                                       Stay Schemin
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %%
'''
Q1.Read the dataframe, check null value if present then do the needful, check
duplicate row , if present then do the needful
'''
df3.isnull().sum()

#no null value

#to check duplicate
df3.duplicated().sum()
df3.drop_duplicates(inplace=True)

# %%
'''
Q2. What is the distribution of popularity among the tracks in the dataset?
Visualize it using a histogram
'''
df3_copy=df3.copy()
print("Popularity statistics:")
print(df3_copy['Popularity'].describe())

# Plot histogram of popularity
plt.figure(figsize=(12, 6))
sns.histplot(df3_copy['Popularity'], bins=30, kde=True, color='#1DB954')
plt.title('Distribution of Track Popularity', fontsize=15)
plt.xlabel('Popularity Score (0-100)', fontsize=12)
plt.ylabel('Number of Tracks', fontsize=12)
plt.axvline(df3_copy['Popularity'].mean(), color='red', linestyle='--',
            label=f'Mean: {df3_copy["Popularity"].mean():.1f}')
plt.axvline(df3_copy['Popularity'].median(), color='green', linestyle='--',
            label=f'Median: {df3_copy["Popularity"].median():.1f}')
plt.legend()
plt.show()
# Out:
# Popularity statistics:
# count    413.000000
# mean      75.384988
# std        9.789010
# min       29.000000
# 25%       70.000000
# 50%       76.000000
# 75%       82.000000
# max       97.000000
# Name: Popularity, dtype: float64

# %%
'''
Q3. Is there any relationship between the popularity and the duration of tracks?
Explore this using a scatter plot
'''


print("Summary Statistics:")
print(df3_copy[['Popularity', 'Duration (ms)']].describe())

# Correlation between popularity and duration
correlation = df3_copy['Popularity'].corr(df3_copy['Duration (ms)'])
print(f"\nCorrelation between Popularity and Duration: {correlation:.3f}")

# Create scatter plot
plt.figure(figsize=(12, 7))
sns.scatterplot(data=df3_copy, x='Duration (ms)', y='Popularity', alpha=0.6, color='royalblue')

# Add title and labels
plt.title('Relationship Between Track Popularity and Duration', fontsize=14)
plt.xlabel('Duration (miliseconds)', fontsize=12)
plt.ylabel('Popularity Score', fontsize=12)
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Summary Statistics:
#        Popularity  Duration (ms)
# count  413.000000     413.000000
# mean    75.384988  206358.496368
# std      9.789010   53980.643666
# min     29.000000   81666.000000
# 25%     70.000000  172185.000000
# 50%     76.000000  201480.000000
# 75%     82.000000  235093.000000
# max     97.000000  501648.000000
#
# Correlation between Popularity and Duration: 0.039

# %%
'''
Q4. Which artist has the highest number of tracks in the dataset? Display the
count of tracks for each artist using a countplot
'''


artist_counts = df3_copy['Artist'].value_counts().reset_index()
artist_counts.columns = ['Artist', 'Track Count']

# Get top 10 artists by track count
top_artists = artist_counts.head(10)

print("Top 10 Artists by Number of Tracks:")
print(top_artists.to_string(index=False))

# Create countplot for top artists
plt.figure(figsize=(12, 6))
sns.barplot(data=top_artists, x='Track Count', y='Artist', palette='viridis')
plt.title('Top 10 Artists by Number of Tracks in Dataset', fontsize=14)
plt.xlabel('Number of Tracks', fontsize=12)
plt.ylabel('Artist', fontsize=12)
plt.grid(axis='x', alpha=0.3)


for i, count in enumerate(top_artists['Track Count']):
    plt.text(count+0.5, i, str(count), va='center', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# Top 10 Artists by Number of Tracks:
#       Artist  Track Count
#        Drake           17
#       Eminem           11
#     Flo Rida           10
#     Ludacris           10
#    Timbaland           10
#           ¥$           10
#    21 Savage           10
#        JAY-Z           10
#    Lil Nas X           10
# Travis Scott            9

# %%
'''
Q5.What are the top 5 least popular tracks in the dataset? Provide the artist
name and track name for each
'''
least_popular = df3.sort_values('Popularity').head(5)[['Artist', 'Track Name', 'Popularity']]

print("Top 5 Least Popular Tracks:")
print(least_popular.to_string(index=False))
# Out:
# Top 5 Least Popular Tracks:
#         Artist                    Track Name  Popularity
#         Pressa Attachments (feat. Coi Leray)          29
#  Justin Bieber                    Intentions          35
# French Montana               Splash Brothers          44
#       Lil Baby                 On Me - Remix          47
#    Wyclef Jean     911 (feat. Mary J. Blige)          48

# %%
'''
Q6. Among the top 5 most popular artists, which artist has the highest
popularity on average? Calculate and display the average popularity for each artist
'''

top_5_artists = df3_copy['Artist'].value_counts().head(5).index.tolist()

top_artists_data = df3_copy[df3_copy['Artist'].isin(top_5_artists)]

avg_popularity = top_artists_data.groupby('Artist')['Popularity'].mean().sort_values(ascending=False).reset_index()

print("Average Popularity for Top 5 Artists (by track count):")
print(avg_popularity.to_string(index=False, float_format="%.2f"))
# Out:
# Average Popularity for Top 5 Artists (by track count):
#    Artist  Popularity
#    Eminem       83.64
#     Drake       82.88
#  Flo Rida       78.00
# Timbaland       69.00
#  Ludacris       63.00

# %%
'''
Q7. For the top 5 most popular artists, what are their most popular tracks? List
the track name for each artist
'''
top_5_artists = df3_copy['Artist'].value_counts().head(5).index.tolist()

most_popular_tracks = df3_copy[df3_copy['Artist'].isin(top_5_artists)] \
    .sort_values('Popularity', ascending=False) \
    .drop_duplicates('Artist') \
    [['Artist', 'Track Name', 'Popularity']] \
    .sort_values('Popularity', ascending=False)

print("Most Popular Tracks for Top 5 Artists:")
print(most_popular_tracks.to_string(index=False))
# Out:
# Most Popular Tracks for Top 5 Artists:
#    Artist                              Track Name  Popularity
#     Drake Rich Baby Daddy (feat. Sexyy Red & SZA)          92
#    Eminem                              Without Me          90
# Timbaland                           The Way I Are          85
#  Flo Rida                      Low (feat. T-Pain)          84
#  Ludacris                            My Chick Bad          67

# %%
'''
Q8. Visualize relationships between multiple numerical variables simultaneously
using a pair plot
'''

top_artists = df3_copy['Artist'].value_counts().head(5).index
df_top = df3_copy[df3_copy['Artist'].isin(top_artists)]

# Create pair plot with hue by artist
plt.figure(figsize=(12, 8))
sns.set_style("whitegrid")
pair_grid = sns.pairplot(data=df_top,
                        vars=['Popularity', 'Duration (ms)'],
                        hue='Artist',
                        palette='viridis',
                        height=4,
                        aspect=1.2,
                        plot_kws={'alpha': 0.7, 's': 80})

pair_grid.fig.suptitle('Relationships Between Popularity and Duration by Top Artists', y=1.02)
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(data=df_top, x='Artist', y='Popularity', palette='viridis')
plt.title('Distribution of Popularity Scores by Top Artist')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
'''
Q9.Does the duration of tracks vary significantly across different artists?
Explore this visually using a box plot or violin plot
'''

# Get top 10 artists by track count
top_artists = df3_copy['Artist'].value_counts().head(10).index
df_top = df3_copy[df3_copy['Artist'].isin(top_artists)]

# Set style
sns.set(style="whitegrid", palette="pastel")
plt.figure(figsize=(14, 8))

# Box plot
plt.subplot(1, 2, 1)
sns.boxplot(data=df_top, x='Duration (ms)', y='Artist')
plt.title('Distribution of Track Durations by Artist (Box Plot)')
plt.xlabel('Duration (minutes)')
plt.ylabel('Artist')

# Violin plot
plt.subplot(1, 2, 2)
sns.violinplot(data=df_top, x='Duration (ms)', y='Artist')
plt.title('Distribution of Track Durations by Artist (Violin Plot)')
plt.xlabel('Duration (minutes)')
plt.ylabel('')

plt.tight_layout()
plt.show()

# Statistical summary
duration_stats = df_top.groupby('Artist')['Duration (ms)'].describe()[['count', 'mean', 'std', 'min', '50%', 'max']]
print("\nDuration Statistics by Artist (minutes):")
print(duration_stats.sort_values('mean', ascending=False).to_string(float_format="%.2f"))
# Out:
# Duration Statistics by Artist (minutes):
#               count      mean      std       min       50%       max
# Artist
# Eminem        11.00 285642.18 58133.60 210800.00 284200.00 404106.00
# Travis Scott   9.00 270723.11 60670.66 191700.00 251249.00 366592.00
# Ludacris      10.00 255682.20 36004.82 201586.00 270806.00 303026.00
# Drake         17.00 241581.53 53991.41 149077.00 239359.00 357706.00
# JAY-Z         10.00 232998.30 50856.40 140746.00 243426.50 284493.00
# Flo Rida      10.00 220676.50 18999.77 190185.00 224455.50 248133.00
# Timbaland     10.00 220084.60 37932.56 174222.00 232213.00 292706.00
# 21 Savage     10.00 215707.10 41243.84 143718.00 202938.50 270697.00
# ¥$            10.00 202406.60 65018.83 111458.00 202347.00 295471.00
# Lil Nas X     10.00 159372.40 35940.04 113000.00 154381.50 212352.00

# %%
'''
Q10. How does the distribution of track popularity vary for different artists?
Visualize this using a swarm plot or a violin plot.
'''
# Filter for artists with at least 5 tracks
artist_counts = df3_copy['Artist'].value_counts()
top_artists = artist_counts[artist_counts >= 5].index.tolist()
filtered_df = df3_copy[df3_copy['Artist'].isin(top_artists)]

# Create the plot
plt.figure(figsize=(12, 8))
sns.violinplot(x='Artist', y='Popularity', data=filtered_df, inner='quartile')

# Customize the plot
plt.title('Distribution of Track Popularity by Artist', fontsize=14)
plt.xlabel('Artist', fontsize=12)
plt.ylabel('Popularity Score', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
